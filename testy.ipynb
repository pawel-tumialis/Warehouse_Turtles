# %%
import networkx as nx

# %%
#tworzenie grafu
plan = nx.DiGraph()
'''
plan.add_node("H01TEST")
plan.add_node("H01TEST_polka")
plan.add_node("H01TEST_polka2")
plan.add_node("H01TEST_korytarz")
'''
plan.add_edge("H01TEST", "H01TEST_polka", weight=4)
plan.add_edge("H01TEST_polka", "H01TEST", weight=4)
plan.add_edge("H01TEST_polka", "H01TEST_polka2", weight=3)
plan.add_edge("H01TEST_polka2", "H01TEST_polka", weight=3)
plan.add_edge("H01TEST_polka2", "H01TEST_korytarz", weight=8)
plan.add_edge("H01TEST_korytarz", "H01TEST_polka2", weight=8)
plan.add_edge("H01TEST_korytarz", "H01TEST", weight=4)

# %%
'''
plan.add_weighted_edges_from([("H01TEST", "H01TEST_polka", 4), ("H01TEST_polka", "H01TEST" , 4)])
plan.add_weighted_edges_from([("H01TEST_polka2", "H01TEST_polka", 4), ("H01TEST_polka", "H01TEST_polka2" , 4)])
plan.add_weighted_edges_from([("H01TEST_polka2", "H01TEST_korytarz", 2), ("H01TEST_korytarz", "H01TEST_polka2", 2)])
plan.add_weighted_edges_from([("H01TEST", "H01TEST_korytarz", 3)])
'''
import matplotlib.pyplot as plt
pos=nx.spring_layout(plan)
nx.draw_networkx(plan,pos)
labels = nx.get_edge_attributes(plan,'weight')
nx.draw_networkx_edge_labels(plan,pos,edge_labels=labels)
#nx.draw(plan, with_labels=True)
# Out:
# {('H01TEST',
#   'H01TEST_polka'): Text(0.3836377134983543, -0.5800672543079535, '4'),
#  ('H01TEST_polka',
#   'H01TEST'): Text(0.3836377134983543, -0.5800672543079535, '4'),
#  ('H01TEST_polka',
#   'H01TEST_polka2'): Text(0.33977488243000314, 0.3525480169072207, '3'),
#  ('H01TEST_polka2',
#   'H01TEST_polka'): Text(0.33977488243000314, 0.3525480169072207, '3'),
#  ('H01TEST_polka2',
#   'H01TEST_korytarz'): Text(-0.3836377134983542, 0.5800672543079535, '8'),
#  ('H01TEST_korytarz',
#   'H01TEST_polka2'): Text(-0.3836377134983542, 0.5800672543079535, '8'),
#  ('H01TEST_korytarz',
#   'H01TEST'): Text(-0.33977488243000303, -0.35254801690722065, '4')}

# %%
from py3dbp import Packer, Bin, Item

packer = Packer()

packer.add_bin(Bin('small-envelope', 11.5, 6.125, 0.25, 10))
packer.add_bin(Bin('large-envelope', 15.0, 12.0, 0.75, 15))
packer.add_bin(Bin('small-box', 8.625, 5.375, 1.625, 70.0))
packer.add_bin(Bin('medium-box', 11.0, 8.5, 5.5, 70.0))
packer.add_bin(Bin('medium-2-box', 13.625, 11.875, 3.375, 70.0))
packer.add_bin(Bin('large-box', 12.0, 12.0, 5.5, 70.0))
packer.add_bin(Bin('large-2-box', 23.6875, 11.75, 3.0, 70.0))

packer.add_item(Item('50g [powder 1]', 3.9370, 1.9685, 1.9685, 1))
packer.add_item(Item('50g [powder 2]', 3.9370, 1.9685, 1.9685, 2))
packer.add_item(Item('50g [powder 3]', 3.9370, 1.9685, 1.9685, 3))
packer.add_item(Item('250g [powder 4]', 7.8740, 3.9370, 1.9685, 4))
packer.add_item(Item('250g [powder 5]', 7.8740, 3.9370, 1.9685, 5))
packer.add_item(Item('250g [powder 6]', 7.8740, 3.9370, 1.9685, 6))
packer.add_item(Item('250g [powder 7]', 7.8740, 3.9370, 1.9685, 7))
packer.add_item(Item('250g [powder 8]', 7.8740, 3.9370, 1.9685, 8))
packer.add_item(Item('250g [powder 9]', 7.8740, 3.9370, 1.9685, 9))

packer.pack()

for b in packer.bins:
    print(":::::::::::", b.string())

    print("FITTED ITEMS:")
    for item in b.items:
        print("====> ", item.string())

    print("UNFITTED ITEMS:")
    for item in b.unfitted_items:
        print("====> ", item.string())

    print("***************************************************")
    print("***************************************************")
# Out:
# ::::::::::: small-envelope(11.500x6.125x0.250, max_weight:10.000) vol(17.609)
# FITTED ITEMS:
# UNFITTED ITEMS:
# ====>  50g [powder 1](3.937x1.968x1.968, weight: 1.000) pos([0, 0, 0]) rt(0) vol(15.248)
# ====>  50g [powder 2](3.937x1.968x1.968, weight: 2.000) pos([Decimal('3.937'), 0, 0]) rt(0) vol(15.248)
# ====>  50g [powder 3](3.937x1.968x1.968, weight: 3.000) pos([Decimal('7.874'), 0, 0]) rt(0) vol(15.248)
# ====>  250g [powder 4](7.874x3.937x1.968, weight: 4.000) pos([Decimal('11.811'), 0, 0]) rt(0) vol(61.008)
# ====>  250g [powder 5](7.874x3.937x1.968, weight: 5.000) pos([Decimal('19.685'), 0, 0]) rt(1) vol(61.008)
# ====>  250g [powder 6](7.874x3.937x1.968, weight: 6.000) pos([0, Decimal('1.968'), 0]) rt(0) vol(61.008)
# ====>  250g [powder 7](7.874x3.937x1.968, weight: 7.000) pos([Decimal('11.811'), Decimal('3.937'), 0]) rt(0) vol(61.008)
# ====>  250g [powder 8](7.874x3.937x1.968, weight: 8.000) pos([0, Decimal('5.905'), 0]) rt(0) vol(61.008)
# ...

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
import pandas as pd
import os
import re

root = tk.Tk()
frame = tk.Frame(root)
frame.pack(side="top", expand=True, fill="both")
#background_image = tk.PhotoImage('./assets/background.png')
#background_label = tk.Label(root, image=background_image)
#background_label.place(x=0, y=0, relwidth=1, relheight=1)

root.title('Warehouse planer')
root.iconbitmap('./assets/planer.ico')
window_width = 300
window_height = 200

screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()

center_x = int(screen_width/2 - window_width / 2)
center_y = int(screen_height/2 - window_height / 2)

root.geometry(f'{window_width}x{window_height}+{center_x}+{center_y}')

def clean_window():
    for widget in frame.winfo_children():
        widget.destroy()

def choose_folder():
    dict_path = filedialog.askdirectory(
    title='Wybierz folder z zamówieniami', initialdir='/')
    finded_csv = 0
    if dict_path != None:
        for file in os.listdir(dict_path):
            if file.endswith(".csv"):
                finded_csv = 1
                break
    if finded_csv == 0:
        messagebox.showerror("Błąd", "Nie znaleziono plików csv")
    else:
        clean_window()
        #kod Wiktora
        tk.Label(frame, text ="This is a new window").pack()


choose_button = tk.Button(
    frame,
    text='Wybierz folder',
    command=choose_folder
)

choose_button.pack(
    ipadx=15,
    ipady=5,
    expand=True
)
#----------------------
import matplotlib.pyplot as plt
import numpy as np
def plot():
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.axes.set_xlim3d(left=0, right=400) 
    ax.axes.set_ylim3d(bottom=600, top=0) 
    ax.axes.set_zlim3d(bottom=0, top=2000)

    ax.bar3d(4, 5, 10, 100, 200, 300, color=(1,0,0,1))
    plt.show()
    input()
    ax.bar3d(200, 300, 400, 100, 200, 300, color=(1,0,1,1))

    plt.show()
    
plot_button = tk.Button(
    frame,
    text='Plot',
    command=plot
)

plot_button.pack(
    ipadx=1,
    ipady=1,
    expand=True
)

# keep the window displaying
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pawel\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\pawel\AppData\Local\Temp\ipykernel_22592\3918862163.py", line 70, in plot
#     ax.plot(bar3d(4, 5, 10, 100, 200, 300, color=(1,0,0,1)))
# NameError: name 'bar3d' is not defined

# %%
import tkinter as tk                
from tkinter import font as tkfont
from tkinter import filedialog
from tkinter import messagebox
import pandas as pd

class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")
        self.title('Warehouse planer')
        self.iconbitmap('./assets/planer.ico')
        window_width = 300
        window_height = 200

        screen_width = self.winfo_screenwidth()
        screen_height = self.winfo_screenheight()

        center_x = int(screen_width/2 - window_width / 2)
        center_y = int(screen_height/2 - window_height / 2)

        self.geometry(f'{window_width}x{window_height}+{center_x}+{center_y}')

        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, SelectedDict, PredictedRoute):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")

        self.app_data = {"path":tk.StringVar()}
        self.show_frame("StartPage")

    def show_frame(self, page_name):
        frame = self.frames[page_name]
        frame.tkraise()
        if arg:
            frame.arg = arg

class StartPage(tk.Frame):
    
    def choose_folder(x):
        dict_path = filedialog.askdirectory(
        title='Wybierz folder z zamówieniami',
        initialdir='/')
        x.controller.show_frame("SelectedDict")

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        #button = tk.Button(self, text="Wybierz folder", command=self.choose_folder)
        #button.pack(ipadx=15,ipady=5,expand=True)
        button = tk.Button(self, text="PlotPlot", command=self.plot_test)
        button.pack(ipadx=15,ipady=5,expand=True)


class SelectedDict(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        print(attr)
        #path = controller.app_data["path"].get()
        label = tk.Label(self, text='self', font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()


class PredictedRoute(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 2", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()
        
class PackagingSimulation(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 2", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()
        

if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()
# Out:
# None

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
 
 
# Create axis
axes = [5, 5, 5]
 
# Create Data
data = np.ones(axes, dtype=np.bool)
 
# Control Transparency
alpha = 1
 
# Control colour
colors = np.empty(axes + [4], dtype=np.float32)
 
colors[0] = [1, 0, 0, alpha]  # red
colors[1] = [0, 1, 0, alpha]  # green
colors[2] = [0, 0, 1, alpha]  # blue
colors[3] = [1, 1, 0, alpha]  # yellow
colors[4] = [1, 1, 1, alpha]  # grey
 
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Voxels is used to customizations of
# the sizes, positions and colors.
ax.voxels(data, facecolors=colors, edgecolors='grey')
# Out:
# C:\Users\pawel\AppData\Local\Temp\ipykernel_22592\1118271952.py:10: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = np.ones(axes, dtype=np.bool)
# {(0, 0, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1663b14d570>,
#  (0, 0, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1666b80b6d0>,
#  (0, 1, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1666b80bac0>,
#  (0, 1, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1666b80beb0>,
#  (0, 2, 0): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1666b8402e0>,
#  (0, 2, 4): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1666b840700>,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.widgets import Button

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.axes.set_xlim3d(left=0, right=400) 
ax.axes.set_ylim3d(bottom=600, top=0) 
ax.axes.set_zlim3d(bottom=0, top=2000)

ax.bar3d(4, 5, 10, 100, 200, 300, color=(1,0,0,1))
ax.bar3d(200, 300, 400, 100, 200, 300, color=(1,0,1,1))


class Callbacks:
    ind = 0
    
    def next(self, event):
        a=0

    def prev(self, event):
        b=0
        
    def first(self, event):
        a=0

    def all(self, event):
        b=0

callback = Callbacks()
ax_all = fig.add_axes([0.2, 0.05, 0.1, 0.1])
ax_first = fig.add_axes([0.4, 0.05, 0.1, 0.1])
axprev = fig.add_axes([0.6, 0.05, 0.1, 0.1])
axnext = fig.add_axes([0.8, 0.05, 0.1, 0.1])
b_all = Button(ax_all, 'Wszystkie')
b_all.on_clicked(callback.all)

b_first = Button(ax_first, 'Pierwszy')
b_first.on_clicked(callback.first)

b_next = Button(axnext, 'Następny')
b_next.on_clicked(callback.next)

b_prev = Button(axprev, 'Poprzedni')
b_prev.on_clicked(callback.prev)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.widgets import Button

freqs = np.arange(2, 20, 3)

fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.2)
t = np.arange(0.0, 1.0, 0.001)
s = np.sin(2*np.pi*freqs[0]*t)
l, = ax.plot(t, s, lw=2)


class Index:
    ind = 0

    def next(self, event):
        self.ind += 1
        i = self.ind % len(freqs)
        ydata = np.sin(2*np.pi*freqs[i]*t)
        l.set_ydata(ydata)
        plt.draw()

    def prev(self, event):
        self.ind -= 1
        i = self.ind % len(freqs)
        ydata = np.sin(2*np.pi*freqs[i]*t)
        l.set_ydata(ydata)
        plt.draw()

callback = Index()
ax_all = fig.add_axes([0.2, 0.05, 0.1, 0.1])
ax_first = fig.add_axes([0.4, 0.05, 0.1, 0.1])
axprev = fig.add_axes([0.6, 0.05, 0.1, 0.1])
axnext = fig.add_axes([0.8, 0.05, 0.1, 0.1])
b_all = Button(ax_all, 'Wszystkie')
b_all.on_clicked(callback.next)

b_first = Button(ax_first, 'Pierwszy')
b_first.on_clicked(callback.next)

b_next = Button(axnext, 'Następny')
b_next.on_clicked(callback.next)

b_prev = Button(axprev, 'Poprzedni')
b_prev.on_clicked(callback.prev)

plt.show()

# %%
import matplotlib.pyplot as plt
img = plt.imread("plan.png")
fig, ax = plt.subplots()
ax.imshow(img)
